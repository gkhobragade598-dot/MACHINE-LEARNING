# %% [markdown]
# ## Business Problem

# %%
# Import Libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
#path = "D:/New folder/Students Marks Prediction.csv"
df = pd.read_csv(r"D:\Machine-Learning\7 May - Students Marks Predictors\student_info.csv")

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.scatter(x = df.study_hours, y = df.student_marks)
plt.xlabel("students study Hours")
plt.ylabel("students marks")
plt.title("scatter plot between students study hours and marks")
plt.show()

# %% [markdown]
# ## prepare the data for Machine Learning algorithms

# %% [markdown]
#  Data Cleaning

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2 = df.fillna(df.mean())

# %%
df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
df2.head()
# Out:
#    study_hours  student_marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.995949          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    200 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
x = df2.drop("student_marks", axis = "columns")
y = df2.drop("study_hours", axis = "columns")
print("shape of x = ", x.shape)
print("shape of y = ", y.shape)
# Out:
# shape of x =  (200, 1)
# shape of y =  (200, 1)

# %%
x
# Out:
#      study_hours
# 0       6.830000
# 1       6.560000
# 2       6.995949
# 3       5.670000
# 4       8.670000
# ..           ...
# 195     7.530000
# 196     8.560000
# 197     8.940000
# 198     6.600000
# 199     8.350000
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      student_marks
# 0            78.50
# 1            76.74
# 2            78.68
# 3            71.82
# 4            84.19
# ..             ...
# 195          81.67
# 196          84.68
# 197          86.75
# 198          78.05
# 199          83.50
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2,random_state = 0)

print("shape of x_train = ", x_train.shape)
print("shape of y_train =", y_train.shape)
print("shape of x_test = ", x_test.shape)
print("shape of y_test = ", y_test.shape)
# Out:
# shape of x_train =  (160, 1)
# shape of y_train = (160, 1)
# shape of x_test =  (40, 1)
# shape of y_test =  (40, 1)

# %% [markdown]
# ## Select a model and train it

# %%
# y = m * x + c
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
lr.coef_ #m
# Out:
# array([[3.93037294]])

# %%
lr.intercept_ #c
# Out:
# array([50.45063632])

# %%
m = 3.93
c = 50.44
y = m * 10 + c
y
# Out:
# 89.74000000000001

# %%
m = 3.93
c = 50.44
y = m * 11 + c
y
# Out:
# 93.67

# %%
lr.predict([[11]]).round(2)
# Out:
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[93.68]])

# %%
lr
# Out:
# LinearRegression()

# %%
#lr.predict([[5]])[0][0].round(2)

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([[83.50507271],
#        [70.84927186],
#        [72.93236952],
#        [85.35234799],
#        [73.20749562],
#        [84.48766595],
#        [80.12495199],
#        [81.85431608],
#        [80.91102657],
#        [82.20804964],
#        [78.98514384],
#        [84.84139951],
#        [77.84533568],
#        [77.68812077],
#        [83.22994661],
#        [85.78468901],
#        [84.9593107 ],
#        [72.61793968],
#        [78.71001773],
#        [79.18166248],
#        [84.2911473 ],
#        [85.6274741 ],
#        [74.74034107],
#        [81.3433676 ],
#        [72.02838374],
#        [80.40007809],
#        [78.98514384],
#        [82.09013845],
#        [77.94732382],
#        [82.24735337],
#        [75.44780819],
#        [84.60557713],
#        [71.63534645],
#        [75.48711192],
#        [70.29901965],
#        [78.98514384],
#        [75.32989701],
#        [84.52696967],
#        [74.07217767],
#        [71.4388278 ]])

# %%
pd.DataFrame(np.c_[x_test, y_test, y_pred], columns = ["study_hours", "actual_marks", "predicted_marks"])
# Out:
#     study_hours  actual_marks  predicted_marks
# 0      8.410000         82.50        83.505073
# 1      5.190000         71.18        70.849272
# 2      5.720000         73.25        72.932370
# 3      8.880000         83.64        85.352348
# 4      5.790000         73.64        73.207496
# 5      8.660000         86.99        84.487666
# 6      7.550000         81.18        80.124952
# 7      7.990000         82.75        81.854316
# 8      7.750000         79.50        80.911027
# 9      8.080000         81.70        82.208050
# 10     7.260000         79.41        78.985144
# 11     8.750000         85.95        84.841400
# 12     6.970000         77.19        77.845336
# 13     6.930000         78.45        77.688121
# 14     8.340000         84.00        83.229947
# 15     8.990000         85.46        85.784689
# 16     8.780000         84.35        84.959311
# 17     5.640000         73.19        72.617940
# 18     7.190000         78.21        78.710018
# ...

# %%
lr.score(x_test, y_test) # variance
# Out:
# 0.9521841793508594

# %%
lr.score(x_train, y_train) # bias
# Out:
# 0.9584528455152638

# %%
plt.scatter(x_train, y_train)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_train, lr.predict(x_train), color = "r")

# %% [markdown]
# ## Save ML Model

# %%
lr
# Out:
# LinearRegression()

# %%
import joblib # create pipeline
joblib.dump(lr, "Desktop.pkl")
# Out:
# ['Desktop.pkl']

# %%
pwd
# Out:
# 'd:\\Machine-Learning\\7 May - Students Marks Predictors'
